# %% [markdown]
# *   Computing Platforms: Set up the Workspace for Machine Learning Projects.  https://ms.pubpub.org/pub/computing
# *  Machine Learning for Predictions. https://ms.pubpub.org/pub/ml-prediction
# * Machine Learning Packages: https://scikit-learn.org/stable/

# %% [markdown]
# # Part I: Import and Inspect Data

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Rising-Stars-by-Sunshine/stats201-tutorial-prediction/main/data/Queried_Data/queried_data.csv',index_col="Unnamed: 0")
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit
# 100  14650515  2022-04-25 00:00:04         0   30000000
# 101  14650516  2022-04-25 00:00:07   3067277   29970705
# 102  14650517  2022-04-25 00:00:09  29927116   29941438
# 103  14650518  2022-04-25 00:00:35  29951281   29970676
# 104  14650519  2022-04-25 00:00:38  15598681   29999943

# %% [markdown]
# # Part II: Prepare the Y varible for Regression

# %% [markdown]
# ## 2.1. Write functions to calculte the Y variable for Regression
#
# *(skip the step if the Y variable already exists)*

# %%
df['theta'] = df['gas_used']/df['gas_limit']
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957

# %% [markdown]
# ## 2.2. Make Sure that the Data Type of Y is "numeric"

# %%
df.dtypes
# Out:
# number         int64
# timestamp     object
# gas_used       int64
# gas_limit      int64
# theta        float64
# dtype: object

# %%
df['theta'] = pd.to_numeric(df['theta'])
df.dtypes
# Out:
# number         int64
# timestamp     object
# gas_used       int64
# gas_limit      int64
# theta        float64
# dtype: object

# %% [markdown]
# # Part III: Prepare the Y variable for Classification

# %% [markdown]
# reference:
#
# https://datatofish.com/if-condition-in-pandas-dataframe/ *italicized text*

# %%
#@title Define the Congestion Threshold
cut = 0.95 #@param {type:"number"}

# %% [markdown]
# ## 3.1. Method 1: If function

# %%
df['congested'] = df['theta'] >= cut
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta  congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000      False
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343      False
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522       True
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353       True
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957      False

# %%
df.loc[(df['theta'] >= cut), 'congested'] = 1
df.loc[(df['theta'] <cut), 'congested'] = 0
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000         0
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343         0
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522         1
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353         1
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957         0

# %% [markdown]
# ## 3.2. Method 2: Lambda function
#
# notes: the best method that I suggest

# %%
df['congested'] = df['theta'].apply(lambda x: 1 if x>= cut else 0)
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta  congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000          0
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343          0
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522          1
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353          1
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957          0

# %% [markdown]
# ## 3.3. Method 3: Cut function

# %% [markdown]
# reference:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html
#
# notes: I do not suggest this method if you are newbies to data science

# %%
df.head()
# Out:
#        number            timestamp  gas_used  gas_limit     theta  congested
# 100  14650515  2022-04-25 00:00:04         0   30000000  0.000000          0
# 101  14650516  2022-04-25 00:00:07   3067277   29970705  0.102343          0
# 102  14650517  2022-04-25 00:00:09  29927116   29941438  0.999522          1
# 103  14650518  2022-04-25 00:00:35  29951281   29970676  0.999353          1
# 104  14650519  2022-04-25 00:00:38  15598681   29999943  0.519957          0

# %%
import numpy as np
 
congested = pd.cut(df['theta'], bins=[0,0.95,1], labels=[0,1]) #might have problems at boundaries
df.insert(3, 'congested2',congested)
df.head()
# Out:
#        number            timestamp  gas_used congested2  gas_limit     theta  \
# 100  14650515  2022-04-25 00:00:04         0        NaN   30000000  0.000000
# 101  14650516  2022-04-25 00:00:07   3067277          0   29970705  0.102343
# 102  14650517  2022-04-25 00:00:09  29927116          1   29941438  0.999522
# 103  14650518  2022-04-25 00:00:35  29951281          1   29970676  0.999353
# 104  14650519  2022-04-25 00:00:38  15598681          0   29999943  0.519957
#
#      congested
# 100          0
# 101          0
# 102          1
# 103          1
# 104          0

# %%
import numpy as np
 
congested = pd.cut(df['theta'], bins=[-1,0.95,2], labels=[0,1]) #avoid the boundary problems
df.insert(3, 'congested3',congested)
df.head()
# Out:
#        number            timestamp  gas_used congested3 congested2  gas_limit  \
# 100  14650515  2022-04-25 00:00:04         0          0        NaN   30000000
# 101  14650516  2022-04-25 00:00:07   3067277          0          0   29970705
# 102  14650517  2022-04-25 00:00:09  29927116          1          1   29941438
# 103  14650518  2022-04-25 00:00:35  29951281          1          1   29970676
# 104  14650519  2022-04-25 00:00:38  15598681          0          0   29999943
#
#         theta  congested
# 100  0.000000          0
# 101  0.102343          0
# 102  0.999522          1
# 103  0.999353          1
# 104  0.519957          0

# %% [markdown]
# # Part IV: Create the X variables

# %% [markdown]
# ## 4.1. Shift the Y to get past values

# %% [markdown]
# reference:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html

# %%
# generate a new variable as the previous 1 observable of your Y variable for regression
df['theta_past'] =df['theta'].shift(1)
df.head()
# Out:
#        number            timestamp  gas_used congested3 congested2  gas_limit  \
# 100  14650515  2022-04-25 00:00:04         0          0        NaN   30000000
# 101  14650516  2022-04-25 00:00:07   3067277          0          0   29970705
# 102  14650517  2022-04-25 00:00:09  29927116          1          1   29941438
# 103  14650518  2022-04-25 00:00:35  29951281          1          1   29970676
# 104  14650519  2022-04-25 00:00:38  15598681          0          0   29999943
#
#         theta  congested  theta_past
# 100  0.000000          0         NaN
# 101  0.102343          0    0.000000
# 102  0.999522          1    0.102343
# 103  0.999353          1    0.999522
# 104  0.519957          0    0.999353

# %% [markdown]
# ## 4.2. Calculate the Moving Averages
#
# references:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html
#
# https://towardsdatascience.com/moving-averages-in-python-16170e20f6c

# %%
#@title Define the Window
window = 10 #@param {type:"number"}

# %%
df['theta_past_ma10']=df['theta_past'].rolling(window=window,min_periods=1).mean()
df.head(20)
# Out:
#        number            timestamp  gas_used congested3 congested2  gas_limit  \
# 100  14650515  2022-04-25 00:00:04         0          0        NaN   30000000
# 101  14650516  2022-04-25 00:00:07   3067277          0          0   29970705
# 102  14650517  2022-04-25 00:00:09  29927116          1          1   29941438
# 103  14650518  2022-04-25 00:00:35  29951281          1          1   29970676
# 104  14650519  2022-04-25 00:00:38  15598681          0          0   29999943
# 105  14650520  2022-04-25 00:00:47  10844553          0          0   30000000
# 106  14650521  2022-04-25 00:00:52   7476517          0          0   30000000
# 107  14650522  2022-04-25 00:00:56         0          0        NaN   30000000
# 108  14650523  2022-04-25 00:00:57  18525539          0          0   30000000
# 109  14650524  2022-04-25 00:01:01  10934632          0          0   30000000
# 110  14650525  2022-04-25 00:01:07  29999057          1          1   30000000
# 111  14650526  2022-04-25 00:01:32  24409144          0          0   30000000
# 112  14650527  2022-04-25 00:01:33  11884890          0          0   30000000
# 113  14650528  2022-04-25 00:01:48  14355250          0          0   30029295
# 114  14650529  2022-04-25 00:01:58  12767931          0          0   30000000
# 115  14650530  2022-04-25 00:02:05  29994586          1          1   30000000
# 116  14650531  2022-04-25 00:02:45  26943935          0          0   30029295
# 117  14650532  2022-04-25 00:02:55    584927          0          0   30058619
# 118  14650533  2022-04-25 00:03:26  30027900          1          1   30029266
# 119  14650534  2022-04-25 00:03:29         0          0        NaN   30058590
#
#         theta  congested  theta_past  theta_past_ma10
# 100  0.000000          0         NaN              NaN
# 101  0.102343          0    0.000000         0.000000
# 102  0.999522          1    0.102343         0.051171
# 103  0.999353          1    0.999522         0.367288
# 104  0.519957          0    0.999353         0.525304
# 105  0.361485          0    0.519957         0.524235
# 106  0.249217          0    0.361485         0.497110
# 107  0.000000          0    0.249217         0.461697
# 108  0.617518          0    0.000000         0.403985
# 109  0.364488          0    0.617518         0.427710
# 110  0.999969          1    0.364488         0.421388
# 111  0.813638          0    0.999969         0.521385
# 112  0.396163          0    0.813638         0.592515
# 113  0.478042          0    0.396163         0.532179
# 114  0.425598          0    0.478042         0.480048
# 115  0.999820          1    0.425598         0.470612
# 116  0.897255          0    0.999820         0.534445
# 117  0.019460          0    0.897255         0.599249
# 118  0.999955          1    0.019460         0.601195
# 119  0.000000          0    0.999955         0.639439

# %% [markdown]
# # Part V Train and Test Split

# %% [markdown]
# *reference*:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html

# %%
from sklearn.model_selection import TimeSeriesSplit
tss = TimeSeriesSplit()
print(tss)
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None)

# %%
# change the train and test split parameters 
tss = TimeSeriesSplit(gap=0, max_train_size=None, n_splits=2, test_size=None)

# %%
for train_idx, test_idx in tss.split(df):
    print("TRAIN:", train_idx, "TEST:", test_idx)
# Out:
# TRAIN: [    0     1     2 ... 21147 21148 21149] TEST: [21150 21151 21152 ... 42297 42298 42299]
# TRAIN: [    0     1     2 ... 42297 42298 42299] TEST: [42300 42301 42302 ... 63447 63448 63449]

# %%
train_idx
# Out:
# array([    0,     1,     2, ..., 42297, 42298, 42299])

# %%
test_idx
# Out:
# array([42300, 42301, 42302, ..., 63447, 63448, 63449])

# %%
train_df = df.filter(items=train_idx, axis=0)
test_df =  df.filter(items=test_idx, axis=0)

# %%
train_df.head()
# Out:
#      number            timestamp  gas_used congested3 congested2  gas_limit  \
# 0  14650615  2022-04-25 00:22:41   3788742          0          0   29970705
# 1  14650616  2022-04-25 00:22:43  29979945          1          1   29999972
# 2  14650617  2022-04-25 00:23:35  29962455          1          1   29970677
# 3  14650618  2022-04-25 00:23:42  29979756          1          1   29999944
# 4  14650619  2022-04-25 00:23:56  23281823          0          0   30000000
#
#       theta  congested  theta_past  theta_past_ma10
# 0  0.126415          0    0.991364         0.557929
# 1  0.999332          1    0.126415         0.562116
# 2  0.999726          1    0.999332         0.562060
# 3  0.999327          1    0.999726         0.597107
# 4  0.776061          0    0.999327         0.675015

# %%
test_df.head()
# Out:
#          number            timestamp  gas_used congested3 congested2  \
# 42300  14692815  2022-05-01 15:40:05  11340559          0          0
# 42301  14692816  2022-05-01 15:40:30  29995034          1          1
# 42302  14692817  2022-05-01 15:40:49   3958965          0          0
# 42303  14692818  2022-05-01 15:40:51   3535970          0          0
# 42304  14692819  2022-05-01 15:40:55   4848119          0          0
#
#        gas_limit     theta  congested  theta_past  theta_past_ma10
# 42300   29970705  0.378388          0    0.999309         0.543044
# 42301   29999972  0.999835          1    0.378388         0.552995
# 42302   30029267  0.131837          0    0.999835         0.627107
# 42303   29999943  0.117866          0    0.131837         0.621367
# 42304   30000000  0.161604          0    0.117866         0.605332

# %% [markdown]
# # Part VI Prepare the Train and Test Data for Classification and Regression

# %% [markdown]
# ## 6.1. Classification

# %% [markdown]
# ### 6.1.1 Define the columns (Y, X) for Classification

# %%
cols_C = ['congested','theta_past_ma10']

# %% [markdown]
# ### 6.1.2 Define the Data Frame of Train and Test Data for Classification

# %%
df_C_train = train_df[cols_C]
df_C_test = test_df[cols_C]

# %% [markdown]
# ### 6.1.3 Export the Train and Test Data for Classification

# %%
df_C_train.head()
# Out:
#    congested  theta_past_ma10
# 0          0         0.557929
# 1          1         0.562116
# 2          1         0.562060
# 3          1         0.597107
# 4          0         0.675015

# %%
df_C_train.to_csv('Classification_Train.csv')

# %%
df_C_test.head()
# Out:
#        congested  theta_past_ma10
# 42300          0         0.543044
# 42301          1         0.552995
# 42302          0         0.627107
# 42303          0         0.621367
# 42304          0         0.605332

# %%
df_C_test.to_csv('Classification_Test.csv')

# %% [markdown]
# ## 6.2 Regression

# %% [markdown]
# ### 6.2.1. Define the columns (Y, X) for Regression

# %%
cols_R = ['theta','theta_past_ma10']

# %% [markdown]
# ### 6.2.2. Define the Data Frame of Train and Test Data for Regression

# %%
df_R_train = train_df[cols_R]
df_R_test = test_df[cols_R]

# %% [markdown]
# ### 6.2.3. Export the Train and Test Data for Regression

# %%
df_R_train.head()
# Out:
#       theta  theta_past_ma10
# 0  0.126415         0.557929
# 1  0.999332         0.562116
# 2  0.999726         0.562060
# 3  0.999327         0.597107
# 4  0.776061         0.675015

# %%
df_R_train.to_csv('Regression_Train.csv')

# %%
df_R_test.head()
# Out:
#           theta  theta_past_ma10
# 42300  0.378388         0.543044
# 42301  0.999835         0.552995
# 42302  0.131837         0.627107
# 42303  0.117866         0.621367
# 42304  0.161604         0.605332

# %%
df_R_test.to_csv('Regression_Test.csv')
